# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib as plt
from matplotlib import pyplot

# %%
# !pip install geopandas
import geopandas
! pip install pycountry
import pycountry 
# !pip install contextily
import contextily as ctx

# %%
boros = geopandas.read_file(geopandas.datasets.get_path("nybb"))
print(boros)

# %%
boros.BoroName

# boro_locations = geopandas.tools.geocode(boros.BoroName)

# boro_locations

img = plt.pyplot.imread("nyc_map.png")
fig, ax = plt.pyplot.subplots(figsize=(15,15))
ax.imshow(img)
# boros = boros.to_crs(epsg=3857)
# base = boros.plot(ax=ax, alpha=0.5, edgecolor='k');


# base = boros.to_crs("EPSG:4326").plot(ax=ax, color="white",   edgecolor='k');
# ctx.add_basemap(ax, zoom=0)

# n = ['Brooklyn Bridge', 'Manhattan Bridge', 'Williamsburg Bridge', 'Queensboro Bridge']
# x = [-74.0,     -73.985,    -73.97,  -73.96]
# y = [40.705,     40.71,     40.72,    40.75]
# s = [150,        100,       100,      100]

bb = ax.scatter(500,    550, color='red',     marker='>', s=200, label='Brooklyn Bridge')
mb = ax.scatter(515,    535, color='yellow',   marker='<', s=200, label='Manhattan Bridge')
wb = ax.scatter(555,    512, color='magenta',  marker='v', s=200, label='Williamsburg Bridge')
qb = ax.scatter(580,    410, color='blue',    marker='v', s=200, label='Queensboro Bridge')

# base.scatter(x,y, s=s, color=['red','green','yellow','blue'])
ax.legend()
ax.grid(True)

# for i, txt in enumerate(n):
#     ax.annotate(txt, (x[i], y[i]))
# boro_locations.plot(ax=ax, color="red");

# %%
# streets = geopandas.read_file('SimplifiedStreets_shp')

# %%
boros.BoroName

# boro_locations = geopandas.tools.geocode(boros.BoroName)

# boro_locations
fig, ax = plt.pyplot.subplots(figsize=(20,20))

boros = boros.to_crs(epsg=3857)
base = boros.plot(ax=ax, alpha=0.5, edgecolor='k');


# base = boros.to_crs("EPSG:4326").plot(ax=ax, color="white",   edgecolor='k');
ctx.add_basemap(ax)

# n = ['Brooklyn Bridge', 'Manhattan Bridge', 'Williamsburg Bridge', 'Queensboro Bridge']
# x = [-74.0,     -73.985,    -73.97,  -73.96]
# y = [40.705,     40.71,     40.72,    40.75]
# s = [150,        100,       100,      100]

# bb = base.scatter(-74.0,    40.705, color='red',    s=150, label='Brooklyn Bridge')
# mb = base.scatter(-73.985,  40.71, color='green',   s=150, label='Manhattan Bridge')
# wb = base.scatter(-73.97,   40.72, color='yellow',  s=150, label='Williamsburg Bridge')
# qb = base.scatter(-73.96,   40.75, color='blue',    s=150, label='Queensboro Bridge')



# base.scatter(x,y, s=s, color=['red','green','yellow','blue'])
# ax.legend()
# ax.grid(True)

# for i, txt in enumerate(n):
#     ax.annotate(txt, (x[i], y[i]))
# boro_locations.plot(ax=ax, color="red");

# %%
df = pd.read_csv('nyc-bicycle-counts.csv')
df.head()
# Out:
#    Index           Date            Day  High Temp (°F)  Low Temp (°F)  \
# 0    0.0  4/1/2016 0:00  4/1/2016 0:00            78.1           66.0
# 1    1.0  4/2/2016 0:00  4/2/2016 0:00            55.0           48.9
# 2    2.0  4/3/2016 0:00  4/3/2016 0:00            39.9           34.0
# 3    3.0  4/4/2016 0:00  4/4/2016 0:00            44.1           33.1
# 4    4.0  4/5/2016 0:00  4/5/2016 0:00            42.1           26.1
#
#    Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 0           0.01           1704.0            3126.0               4115.0
# 1           0.15            827.0            1646.0               2565.0
# 2           0.09            526.0            1232.0               1695.0
# 3           0.47            521.0            1067.0               1440.0
# 4           0.00           1416.0            2617.0               3081.0
#
#    Queensboro Bridge    Total
# 0             2552.0  11497.0
# 1             1884.0   6922.0
# 2             1306.0   4759.0
# 3             1307.0   4335.0
# 4             2357.0   9471.0

# %%
df.shape
# Out:
# (30, 11)

# %%
df['High Temp (°F)'].corr(df['Total'])
# Out:
# 0.7433437005618654

# %%
a_dims = (12, 8)
fig, ax = pyplot.subplots(figsize=a_dims)
ax = plt.pyplot.gca()
ax.set_title("Correlation Total and High Temp (°F): " +str( round(df['High Temp (°F)'].corr(df['Total']) ,3)) )
sns.regplot(data=df, x="High Temp (°F)", y="Total", marker="+", color="red")
ax.set_ylabel("Total")
# Out:
# C:\Users\madseg\AppData\Roaming\Python\Python35\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Total')

# %%
df['Low Temp (°F)'].corr(df['Total'])
a_dims = (12, 8)
fig, ax = pyplot.subplots(figsize=a_dims)
ax = plt.pyplot.gca()
ax.set_title("Correlation Total and Low Temp (°F): " +str( round(df['Low Temp (°F)'].corr(df['Total']) ,3)) )
sns.regplot(data=df, x="Low Temp (°F)", y="Total", marker="+", color="blue")
ax.set_ylabel("Total")
# Out:
# C:\Users\madseg\AppData\Roaming\Python\Python35\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0,0.5,'Total')

# %%
df['Precipitation'] = df['Precipitation'].astype(float)
df['Precipitation'].corr(df['Total'])
a_dims = (12, 8)
fig, ax = pyplot.subplots(figsize=a_dims)
ax = plt.pyplot.gca()
ax.set_title("Correlation Total and Precipitation: " +str( round(df['Precipitation'].corr(df['Total']) ,3)) )
sns.regplot(data=df, x="Precipitation", y="Total", marker="+", color="purple")
ax.set_ylabel("Total")

# %%
df = pd.read_csv('nyc-bicycle-counts.csv')

# %%
df['bridgeName'] = df[['Brooklyn Bridge',	'Manhattan Bridge',	'Williamsburg Bridge',	'Queensboro Bridge']].idxmax(axis=1)
df.head()
# Out:
#    Index           Date            Day  High Temp (°F)  Low Temp (°F)  \
# 0      0  4/1/2016 0:00  4/1/2016 0:00            78.1           66.0
# 1      1  4/2/2016 0:00  4/2/2016 0:00            55.0           48.9
# 2      2  4/3/2016 0:00  4/3/2016 0:00            39.9           34.0
# 3      3  4/4/2016 0:00  4/4/2016 0:00            44.1           33.1
# 4      4  4/5/2016 0:00  4/5/2016 0:00            42.1           26.1
#
#    Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 0           0.01             1704              3126                 4115
# 1           0.15              827              1646                 2565
# 2           0.09              526              1232                 1695
# 3           0.47              521              1067                 1440
# 4           0.00             1416              2617                 3081
#
#    Queensboro Bridge  Total           bridgeName
# 0               2552  11497  Williamsburg Bridge
# 1               1884   6922  Williamsburg Bridge
# 2               1306   4759  Williamsburg Bridge
# 3               1307   4335  Williamsburg Bridge
# 4               2357   9471  Williamsburg Bridge

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics 


# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(df[['High Temp (°F)','Low Temp (°F)',	'Precipitation']], df['bridgeName'], test_size=0.3, random_state=1) # 70% training and 30% test

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree
fig = pyplot.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=X_train.columns,  
                   class_names='bridgeName',
                   filled=True)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- class: 0

# %%
df['bridgeName'] = df[['Brooklyn Bridge',	'Manhattan Bridge',	'Queensboro Bridge']].idxmax(axis=1)
df.head()
# Out:
#    Index           Date            Day  High Temp (°F)  Low Temp (°F)  \
# 0      0  4/1/2016 0:00  4/1/2016 0:00            78.1           66.0
# 1      1  4/2/2016 0:00  4/2/2016 0:00            55.0           48.9
# 2      2  4/3/2016 0:00  4/3/2016 0:00            39.9           34.0
# 3      3  4/4/2016 0:00  4/4/2016 0:00            44.1           33.1
# 4      4  4/5/2016 0:00  4/5/2016 0:00            42.1           26.1
#
#    Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 0           0.01             1704              3126                 4115
# 1           0.15              827              1646                 2565
# 2           0.09              526              1232                 1695
# 3           0.47              521              1067                 1440
# 4           0.00             1416              2617                 3081
#
#    Queensboro Bridge  Total         bridgeName
# 0               2552  11497   Manhattan Bridge
# 1               1884   6922  Queensboro Bridge
# 2               1306   4759  Queensboro Bridge
# 3               1307   4335  Queensboro Bridge
# 4               2357   9471   Manhattan Bridge

# %%
df.tail()
# Out:
#      Index            Date             Day  High Temp (°F)  Low Temp (°F)  \
# 205    205  4/26/2016 0:00  4/26/2016 0:00            60.1           46.9
# 206    206  4/27/2016 0:00  4/27/2016 0:00            62.1           46.9
# 207    207  4/28/2016 0:00  4/28/2016 0:00            57.9           48.0
# 208    208  4/29/2016 0:00  4/29/2016 0:00            57.0           46.9
# 209    209  4/30/2016 0:00  4/30/2016 0:00            64.0           48.0
#
#      Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 205           0.24             1997              3520                 4559
# 206           0.00             3343              5606                 6577
# 207           0.00             2486              4152                 5336
# 208           0.05             2375              4178                 5053
# 209           0.00             3199              4952                 5675
#
#      Queensboro Bridge  Total        bridgeName
# 205               2929  13005  Manhattan Bridge
# 206               4388  19914  Manhattan Bridge
# 207               3657  15631  Manhattan Bridge
# 208               3348  14954  Manhattan Bridge
# 209               3606  17432  Manhattan Bridge

# %%
df['Brooklyn Bridge Percent Change'] = (df['Brooklyn Bridge']-df['Brooklyn Bridge'].mean())/df['Brooklyn Bridge'].std()
df['Manhattan Bridge Percent Change'] = (df['Manhattan Bridge']-df['Manhattan Bridge'].mean())/df['Manhattan Bridge'].std()
df['Williamsburg Bridge Percent Change'] = (df['Williamsburg Bridge']-df['Williamsburg Bridge'].mean())/df['Williamsburg Bridge'].std()
df['Queensboro Bridge Percent Change'] = (df['Queensboro Bridge']-df['Queensboro Bridge'].mean())/df['Queensboro Bridge'].std()

df['zScore'] = df[['Brooklyn Bridge Percent Change','Manhattan Bridge Percent Change','Williamsburg Bridge Percent Change', 'Queensboro Bridge Percent Change']].max(axis=1)


conditions = [
    (df['zScore'] == (df['Brooklyn Bridge']-df['Brooklyn Bridge'].mean())/df['Brooklyn Bridge'].std()),
    (df['zScore'] == (df['Manhattan Bridge']-df['Manhattan Bridge'].mean())/df['Manhattan Bridge'].std()),
    (df['zScore'] == (df['Williamsburg Bridge']-df['Williamsburg Bridge'].mean())/df['Williamsburg Bridge'].std()),
    (df['zScore'] == (df['Queensboro Bridge']-df['Queensboro Bridge'].mean())/df['Queensboro Bridge'].std())
    ]

# create a list of the values we want to assign for each condition
values = ['Brooklyn Bridge', 'Manhattan Bridge', 'Williamsburg Bridge', 'Queensboro Bridge']

df['Popular_bridge'] = np.select(conditions, values, default= df['zScore'])

# %%
df.head()
# Out:
#    Index           Date            Day  High Temp (°F)  Low Temp (°F)  \
# 0      0  4/1/2016 0:00  4/1/2016 0:00            78.1           66.0
# 1      1  4/2/2016 0:00  4/2/2016 0:00            55.0           48.9
# 2      2  4/3/2016 0:00  4/3/2016 0:00            39.9           34.0
# 3      3  4/4/2016 0:00  4/4/2016 0:00            44.1           33.1
# 4      4  4/5/2016 0:00  4/5/2016 0:00            42.1           26.1
#
#    Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 0           0.01             1704              3126                 4115
# 1           0.15              827              1646                 2565
# 2           0.09              526              1232                 1695
# 3           0.47              521              1067                 1440
# 4           0.00             1416              2617                 3081
#
#    Queensboro Bridge  Total         bridgeName  \
# 0               2552  11497   Manhattan Bridge
# 1               1884   6922  Queensboro Bridge
# 2               1306   4759  Queensboro Bridge
# 3               1307   4335  Queensboro Bridge
# 4               2357   9471   Manhattan Bridge
#
#    Brooklyn Bridge Percent Change  Manhattan Bridge Percent Change  \
# 0                       -0.576449                        -0.541747
# 1                       -1.470218                        -1.409919
# 2                       -1.776973                        -1.652773
# 3                       -1.782069                        -1.749562
# 4                       -0.869956                        -0.840328
#
#    Williamsburg Bridge Percent Change  Queensboro Bridge Percent Change  \
# 0                           -0.412045                         -0.728554
# 1                           -1.266492                         -1.336239
# 2                           -1.746085                         -1.862050
# 3                           -1.886655                         -1.861140
# 4                           -0.982044                         -0.905947
#
#      zScore       Popular_bridge
# 0 -0.412045  Williamsburg Bridge
# 1 -1.266492  Williamsburg Bridge
# 2 -1.652773     Manhattan Bridge
# 3 -1.749562     Manhattan Bridge
# 4 -0.840328     Manhattan Bridge

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(df[['High Temp (°F)','Low Temp (°F)',	'Precipitation']], df['Popular_bridge'], test_size=0.3, random_state=1) # 70% training and 30% test

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree
fig = pyplot.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=X_train.columns,  
                   class_names='bridgeName',
                   filled=True)
